# %%
set.seed(20190708)
genes <- paste("gene",1:1000,sep="")
x <- list(
  A = sample(genes,300), 
  B = sample(genes,525), 
  C = sample(genes,440),
  D = sample(genes,350)
  )

# %%
#if (!require(devtools)) install.packages("devtools")
devtools::install_github("gaospecial/ggVennDiagram")
# Out:
# Downloading GitHub repo gaospecial/ggVennDiagram@HEAD
# utf8        (1.2.2  -> 1.2.3 ) [CRAN]
# dplyr       (1.0.10 -> 1.1.0 ) [CRAN]
# fs          (1.5.2  -> 1.6.0 ) [CRAN]
# sass        (0.4.4  -> 0.4.5 ) [CRAN]
# tinytex     (0.42   -> 0.44  ) [CRAN]
# bslib       (0.4.1  -> 0.4.2 ) [CRAN]
# xfun        (0.35   -> 0.37  ) [CRAN]
# highr       (0.9    -> 0.10  ) [CRAN]
# evaluate    (0.18   -> 0.20  ) [CRAN]
# rmarkdown   (2.18   -> 2.20  ) [CRAN]
# knitr       (1.41   -> 1.42  ) [CRAN]
# wk          (NA     -> 0.7.1 ) [CRAN]
# e1071       (1.7-12 -> 1.7-13) [CRAN]
# htmlwidgets (1.5.4  -> 1.6.1 ) [CRAN]
# units       (NA     -> 0.8-1 ) [CRAN]
# s2          (NA     -> 1.1.2 ) [CRAN]
# yulab.utils (0.0.5  -> 0.0.6 ) [CRAN]
# RVenn       (NA     -> 1.1.0 ) [CRAN]
# sf          (NA     -> 1.0-9 ) [CRAN]
# Installing 19 packages: utf8, dplyr, fs, sass, tinytex, bslib, xfun, highr, evaluate, rmarkdown, knitr, wk, e1071, htmlwidgets, units, s2, yulab.utils, RVenn, sf
# The downloaded binary packages are in
# 	/var/folders/3f/6pzn2nyn32d7wthyxkzsqyxcdrtvym/T//RtmpiZXZb1/downloaded_packages
# ── R CMD build ─────────────────────────────────────────────────────────────────
# ✔  checking for file ‘/private/var/folders/3f/6pzn2nyn32d7wthyxkzsqyxcdrtvym/T/RtmpiZXZb1/remotes14ee45b5ca15/gaospecial-ggVennDiagram-4cbfb5a/DESCRIPTION’ (358ms)
# ─  preparing ‘ggVennDiagram’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
#    Omitted ‘LazyData’ from DESCRIPTION
# ─  building ‘ggVennDiagram_1.2.2.tar.gz’
#    Warning: invalid uid value replaced by that for user 'nobody'
#    Warning: invalid gid value replaced by that for user 'nobody'

# %%
library("ggVennDiagram")
# Out:
# Error in library("ggVennDiagram"): there is no package called ‘ggVennDiagram’
# Traceback:
#
# 1. library("ggVennDiagram")

# %%
library("ggVennDiagram")
# Default plot
ggVennDiagram(x)
# Out:
# plot without title

# %%
# Remove labels background color
ggVennDiagram(x, label_alpha = 0)
# Out:
# plot without title

# %%
# Change category names
# Change the gradient fill color
ggVennDiagram(
  x, label_alpha = 0,
  category.names = c("Stage 1","Stage 2","Stage 3", "Stage4")
  ) +
  ggplot2::scale_fill_gradient(low="blue",high = "yellow")
# Out:
# plot without title

# %%
ggVennDiagram(x[1:3], label_alpha = 0)
# Out:
# plot without title

# %%
ggVennDiagram(x[1:2], label_alpha = 0)
# Out:
# plot without title

# %%
if (!require(devtools)) install.packages("devtools")
devtools::install_github("yanlinlin82/ggvenn")
# Out:
# Loading required package: devtools
#
# Loading required package: usethis
#
# Downloading GitHub repo yanlinlin82/ggvenn@HEAD
# ── R CMD build ─────────────────────────────────────────────────────────────────
# ✔  checking for file ‘/private/var/folders/3f/6pzn2nyn32d7wthyxkzsqyxcdrtvym/T/RtmpiZXZb1/remotes14ee4f68f065/yanlinlin82-ggvenn-306a330/DESCRIPTION’ (348ms)
# ─  preparing ‘ggvenn’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘ggvenn_0.1.9.tar.gz’
#    Warning: invalid uid value replaced by that for user 'nobody'
#    Warning: invalid gid value replaced by that for user 'nobody'

# %%
library("ggvenn")
# Out:
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: grid
#
# Loading required package: ggplot2

# %%
library("ggvenn")
# Default plot
ggvenn(x)
# Out:
# plot without title

# %%
# Change category names
# Change the fill color
names(x) <- c("Stage 1","Stage 2","Stage 3", "Stage4")
ggvenn(
  x, 
  fill_color = c("#0073C2FF", "#EFC000FF", "#868686FF", "#CD534CFF"),
  stroke_size = 0.5, set_name_size = 4
  )
# Out:
# plot without title

# %%
ggvenn(
  x, columns = c("Stage 1", "Stage 2", "Stage 3"),
  stroke_size = 0.5
  )
# Out:
# plot without title

# %%
ggvenn(
  x, columns = c("Stage 1", "Stage 2"),
  stroke_size = 0.5
  )
# Out:
# plot without title
